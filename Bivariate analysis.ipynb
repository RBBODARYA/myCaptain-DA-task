# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Record of Productivity level

# %%
Time_of_day =["morining","Afternoon","Evening","Night"]
P_level =[4,2,1,5]

# %% [markdown]
# ### Performing Bivariate analysis using bar graph

# %%
plt.bar(Time_of_day,P_level,color="g")
plt.xlabel("TIME OF DAY")
plt.ylabel("PRODUCTIVITY LEVEL")
plt.title("PERFORMANCE THROUGHOUT THE DAY")
# Out:
# Text(0.5, 1.0, 'PERFORMANCE THROUGHOUT THE DAY')

# %% [markdown]
# ### After performing a bivariate analysis on my performance level throughout the day it is irrfutable that my productivity level affected by the time of the day. Hence, the expected result holds true.
